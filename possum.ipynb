# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('datasets/possum.csv')
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.drop(columns=['case'],inplace=True)

# %%
plt.pie(df['Pop'].value_counts(),labels=df['Pop'].value_counts().index)
plt.title('Population')
plt.legend()
plt.show()

# %%
plt.pie(df['sex'].value_counts(),labels=df['sex'].value_counts().index)
plt.title('Gender')
plt.legend()
plt.show()

# %%
sns.distplot(df['age'])
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10648\2799180019.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])

# %%
fig,ax=plt.subplots(3,3)
sns.histplot(df['belly'],ax=ax[0][0])
sns.histplot(df['chest'],ax=ax[0][1])
sns.histplot(df['earconch'],ax=ax[0][2])
sns.histplot(df['eye'],ax=ax[1][0])
sns.histplot(df['footlgth'],ax=ax[1][1])
sns.histplot(df['hdlngth'],ax=ax[1][2])
sns.histplot(df['skullw'],ax=ax[2][0])
sns.histplot(df['taill'],ax=ax[2][1])
sns.histplot(df['totlngth'],ax=ax[2][2])
plt.tight_layout()
plt.show()

# %%
fig,ax=plt.subplots(3,3)
sns.violinplot(df['belly'],ax=ax[0][0])
sns.violinplot(df['chest'],ax=ax[0][1])
sns.violinplot(df['earconch'],ax=ax[0][2])
sns.violinplot(df['eye'],ax=ax[1][0])
sns.violinplot(df['footlgth'],ax=ax[1][1])
sns.violinplot(df['hdlngth'],ax=ax[1][2])
sns.violinplot(df['skullw'],ax=ax[2][0])
sns.violinplot(df['taill'],ax=ax[2][1])
sns.violinplot(df['totlngth'],ax=ax[2][2])
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['sex']=le.fit_transform(df['sex'])
df['Pop']=le.fit_transform(df['Pop'])
df.head()
# Out:
#    site  Pop  sex  age  hdlngth  skullw  totlngth  taill  footlgth  earconch  \
# 0     1    0    1  8.0     94.1    60.4      89.0   36.0      74.5      54.5
# 1     1    0    0  6.0     92.5    57.6      91.5   36.5      72.5      51.2
# 2     1    0    0  6.0     94.0    60.0      95.5   39.0      75.4      51.9
# 3     1    0    0  6.0     93.2    57.1      92.0   38.0      76.1      52.2
# 4     1    0    0  2.0     91.5    56.3      85.5   36.0      71.0      53.2
#
#     eye  chest  belly
# 0  15.2   28.0   36.0
# 1  16.0   28.5   33.0
# 2  15.5   30.0   34.0
# 3  15.2   28.0   34.0
# 4  15.1   28.5   33.0

# %%
plt.figure(figsize=(10, 6)) 
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.head()
# Out:
#    site  Pop  sex  age  hdlngth  skullw  totlngth  taill  footlgth  earconch  \
# 0     1    0    1  8.0     94.1    60.4      89.0   36.0      74.5      54.5
# 1     1    0    0  6.0     92.5    57.6      91.5   36.5      72.5      51.2
# 2     1    0    0  6.0     94.0    60.0      95.5   39.0      75.4      51.9
# 3     1    0    0  6.0     93.2    57.1      92.0   38.0      76.1      52.2
# 4     1    0    0  2.0     91.5    56.3      85.5   36.0      71.0      53.2
#
#     eye  chest  belly
# 0  15.2   28.0   36.0
# 1  16.0   28.5   33.0
# 2  15.5   30.0   34.0
# 3  15.2   28.0   34.0
# 4  15.1   28.5   33.0

# %%
df.describe()
# Out:
#              site         Pop         sex         age     hdlngth      skullw  \
# count  104.000000  104.000000  104.000000  102.000000  104.000000  104.000000
# mean     3.625000    0.557692    0.586538    3.833333   92.602885   56.883654
# std      2.349086    0.499066    0.494839    1.909244    3.573349    3.113426
# min      1.000000    0.000000    0.000000    1.000000   82.500000   50.000000
# 25%      1.000000    0.000000    0.000000    2.250000   90.675000   54.975000
# 50%      3.000000    1.000000    1.000000    3.000000   92.800000   56.350000
# 75%      6.000000    1.000000    1.000000    5.000000   94.725000   58.100000
# max      7.000000    1.000000    1.000000    9.000000  103.100000   68.600000
#
#          totlngth       taill    footlgth    earconch         eye       chest  \
# count  104.000000  104.000000  103.000000  104.000000  104.000000  104.000000
# mean    87.088462   37.009615   68.459223   48.130769   15.046154   27.000000
# ...

# %%
df.corr()
# Out:
#               site       Pop       sex       age   hdlngth    skullw  \
# site      1.000000  0.892326  0.232817 -0.131423 -0.163646 -0.083548
# Pop       0.892326  1.000000  0.195811 -0.086827  0.001267  0.065908
# sex       0.232817  0.195811  1.000000 -0.064442  0.107200  0.080014
# age      -0.131423 -0.086827 -0.064442  1.000000  0.319022  0.285107
# hdlngth  -0.163646  0.001267  0.107200  0.319022  1.000000  0.710827
# skullw   -0.083548  0.065908  0.080014  0.285107  0.710827  1.000000
# totlngth -0.260843 -0.078666 -0.160200  0.260280  0.691094  0.526413
# taill     0.380444  0.490856 -0.040917  0.118241  0.287429  0.255921
# footlgth -0.783009 -0.793156 -0.123820  0.126190  0.391605  0.275059
# earconch -0.790716 -0.883293 -0.091559  0.053405  0.121463 -0.000537
# eye      -0.036987  0.148594  0.188371  0.235553  0.347175  0.321991
# chest    -0.345494 -0.194957 -0.139074  0.334209  0.631498  0.629737
# belly    -0.175266 -0.024788 -0.090777  0.354298  0.562663  0.451838
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   site      104 non-null    int64
#  1   Pop       104 non-null    int32
#  2   sex       104 non-null    int32
#  3   age       102 non-null    float64
#  4   hdlngth   104 non-null    float64
#  5   skullw    104 non-null    float64
#  6   totlngth  104 non-null    float64
#  7   taill     104 non-null    float64
#  8   footlgth  103 non-null    float64
#  9   earconch  104 non-null    float64
#  10  eye       104 non-null    float64
#  11  chest     104 non-null    float64
#  12  belly     104 non-null    float64
# dtypes: float64(10), int32(2), int64(1)
# memory usage: 9.9 KB

# %%
df.columns
# Out:
# Index(['site', 'Pop', 'sex', 'age', 'hdlngth', 'skullw', 'totlngth', 'taill',
#        'footlgth', 'earconch', 'eye', 'chest', 'belly'],
#       dtype='object')

# %%
df.shape
# Out:
# (104, 13)

# %%
df.isna().sum()
# Out:
# site        0
# Pop         0
# sex         0
# age         2
# hdlngth     0
# skullw      0
# totlngth    0
# taill       0
# footlgth    1
# earconch    0
# eye         0
# chest       0
# belly       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
x=df[['hdlngth', 'skullw', 'totlngth', 'taill','footlgth', 'eye', 'chest', 'belly']]
y=df['age']
dd = pd.concat([x, y], axis=1)

# %%
dd.head()
# Out:
#    hdlngth  skullw  totlngth  taill  footlgth   eye  chest  belly  age
# 0     94.1    60.4      89.0   36.0      74.5  15.2   28.0   36.0  8.0
# 1     92.5    57.6      91.5   36.5      72.5  16.0   28.5   33.0  6.0
# 2     94.0    60.0      95.5   39.0      75.4  15.5   30.0   34.0  6.0
# 3     93.2    57.1      92.0   38.0      76.1  15.2   28.0   34.0  6.0
# 4     91.5    56.3      85.5   36.0      71.0  15.1   28.5   33.0  2.0

# %%
sns.pairplot(dd)
plt.plot()
# Out:
# []

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('MSE: ',mean_squared_error(y_pred,y_test))
print('RMSE: ',root_mean_squared_error(y_pred,y_test))
print('MAE: ',mean_absolute_error(y_pred,y_test))
# Out:
# MSE:  4.524235916227938
# RMSE:  2.1270251329563403
# MAE:  1.7779907976003853

# %%
from sklearn.linear_model import Lasso
model=Lasso()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('MSE: ',mean_squared_error(y_pred,y_test))
print('RMSE: ',root_mean_squared_error(y_pred,y_test))
print('MAE: ',mean_absolute_error(y_pred,y_test))
# Out:
# MSE:  3.8155944581676806
# RMSE:  1.9533546677876192
# MAE:  1.6862704825112707

# %%
from sklearn.linear_model import Ridge
model=Ridge()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('MSE: ',mean_squared_error(y_pred,y_test))
print('RMSE: ',root_mean_squared_error(y_pred,y_test))
print('MAE: ',mean_absolute_error(y_pred,y_test))
# Out:
# MSE:  4.512593175241046
# RMSE:  2.1242865096876753
# MAE:  1.7761044741087406

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('MSE: ',mean_squared_error(y_pred,y_test))
print('RMSE: ',root_mean_squared_error(y_pred,y_test))
print('MAE: ',mean_absolute_error(y_pred,y_test))
# Out:
# MSE:  3.9216523809523816
# RMSE:  1.9803162325629666
# MAE:  1.6728571428571426

# %%
import xgboost as xg
model=xg.XGBRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print('MSE: ',mean_squared_error(y_pred,y_test))
print('RMSE: ',root_mean_squared_error(y_pred,y_test))
print('MAE: ',mean_absolute_error(y_pred,y_test))
# Out:
# MSE:  4.0720143002085285
# RMSE:  2.0179232642022167
# MAE:  1.6266867546808153
